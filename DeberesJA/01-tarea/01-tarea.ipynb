# %%
import os as jump
import sys
import fileinput

class Genero: 
    def __init__(self, id_genero, nombre_genero, estilo, ambiente, publico, animacion, pelicula ):
        self.id_genero = id_genero
        self.nombre_genero = nombre_genero
        self.estilo = estilo
        self.ambiente = ambiente
        self.publico = publico
        self.animacion = animacion
        self.pelicula = pelicula
    def agregar_genero(genero):#Añadir genero
        try:
            path = "./Genero.txt"
            archivo_genero = open(path, 'a')
            for id_genero, nombre_genero, estilo, ambiente, publico, animacion, pelicula in genero:
                archivo_genero.write(str(id_genero)+":"+str(nombre_genero)+":"+str(estilo)+":"
                                     +str(ambiente)+":"+str(publico)+":"+str(animacion)+":"+str(pelicula)+"\n")
                
                
            print("Genero Guardado")
            archivo_genero.close()
        except Exception as error:
            print("Error al insertar Genero"+error)
    def buscar_genero(indice):#buqueda de un genero 
        try:
            genero = []
            path = "./Genero.txt"
            archivo_genero = open(path, 'r')
            for line in archivo_genero:
                id_genero, nombre_genero, estilo, ambiente, publico, animacion, pelicula = line.rstrip("\n").split(":")
                genero.append(((int(id_genero), nombre_genero, estilo, ambiente, int(publico), bool(animacion), pelicula)))
                valor = indice in nombre_genero
                print("Genero Encontrado")
                
                if valor: 
                    print(genero)
            archivo_genero.close()
        except Exception as error:
            print("No se encontro"+ str(error))
    def eliminar_genero(indice):#Eliminacion de genero 
        try:
            genero = []
            path = "./Genero.txt"
            archivo_genero = open(path, 'r')
            path_temp = "./GeneroTemporal.txt"
            archivo_ge_temp = open(path_temp, 'w')
            for line in archivo_genero:
                id_genero, nombre_genero, estilo, ambiente, publico, animacion, pelicula = line.rstrip("\n").split(":")
                genero.append(((int(id_genero), nombre_genero, estilo, ambiente, int(publico), bool(animacion), pelicula)))
                valor = indice in nombre_genero
                if valor:
                    line_encontrada = line
            archivo_genero.close()
            genero = []
            path = "./Genero.txt"
            archivo_genero = open(path, 'r')
            path_temp = "./GeneroTemporal.txt"
            archivo_ge_temp = open(path_temp, 'w')
            for line in archivo_genero:
                id_genero, nombre_genero, estilo, ambiente, publico, animacion, pelicula = line.rstrip("\n").split(":")
                genero.append(((int(id_genero), nombre_genero, estilo, ambiente, int(publico), bool(animacion), pelicula)))
                valor = indice in nombre_genero
                if valor:
                    line_encontrada = line
            archivo_genero.close()
            path = "./Genero.txt"
            archivo_genero = open(path, 'r')
            for nueva_linea in archivo_genero:
                if line_encontrada != nueva_linea:
                    archivo_ge_temp.write(nueva_linea)
            archivo_genero.close()
            archivo_ge_temp.close()
            path = "./Genero.txt"
            archivo_genero = open(path, 'w')
            path_temp = "./GeneroTemporal.txt"
            archivo_ge_temp = open(path_temp, 'r')
            for line_copiada in archivo_ge_temp:
                archivo_genero.write(line_copiada)
            archivo_genero.close()
            print("Se elimino exitosamente")
            archivo_ge_temp.close()
        except Exception as error:
            print("No encontro y no se pudo borrar"+error)

        
    def modificar_genero(indice): #Modificacion del genero
        try:
            genero = []
            path = "./Genero.txt"
            archivo_genero = open(path, 'r')
            path_temp = "./GeneroTemporal.txt"
            archivo_ge_temp = open(path_temp, 'w')
            for line in archivo_genero:
                id_genero, nombre_genero, estilo, ambiente, publico, animacion, pelicula = line.rstrip("\n").split(":")
                genero.append(((int(id_genero), nombre_genero, estilo, ambiente, int(publico), bool(animacion), pelicula)))
                valor = indice in nombre_genero
                if valor:
                    line_encontrada = line
            archivo_genero.close()
            genero = []
            path = "./Genero.txt"
            archivo_genero = open(path, 'r')
            path_temp = "./GeneroTemporal.txt"
            archivo_ge_temp = open(path_temp, 'w')
            for line in archivo_genero:
                id_genero, nombre_genero, estilo, ambiente, publico, animacion, pelicula = line.rstrip("\n").split(":")
                genero.append(((int(id_genero), nombre_genero, estilo, ambiente, int(publico), bool(animacion), pelicula)))
                valor = indice in nombre_genero
                if valor:
                    line_encontrada = line
            archivo_genero.close()
            path = "./Genero.txt"
            archivo_genero = open(path, 'r')
            for nueva_linea in archivo_genero:
                if line_encontrada != nueva_linea:
                    archivo_ge_temp.write(nueva_linea)
            archivo_genero.close()
            archivo_ge_temp.close()
            path = "./Genero.txt"
            archivo_genero = open(path, 'w')
            path_temp = "./GeneroTemporal.txt"
            archivo_ge_temp = open(path_temp, 'r')
            for line_copiada in archivo_ge_temp:
                archivo_genero.write(line_copiada)
            archivo_genero.close()
            archivo_ge_temp.close()
            print("Registro encontrado")
            #Formateo 
            id_genero = input("Nuevo ID: ")
            nombre_genero = input(" Nuevo Nombre: ")
            estilo = input("Nuevo Estilo: ")
            ambiente = input("Nuevo Ambientacion: ")
            publico = input("Nueva Edad minima Publico: ")
            animacion = input("Nueva Animacion(True o False): ")
            pelicula = input("Nueva Pelicula: ")
            genero = [(id_genero,nombre_genero,estilo,ambiente,publico,animacion, pelicula)]

            path = "./Genero.txt"
            archivo_genero = open(path, 'a')
            for id_genero, nombre_genero, estilo, ambiente, publico, animacion, pelicula in genero:
                archivo_genero.write(str(id_genero)+":"+str(nombre_genero)+":"+str(estilo)+":"
                                        +str(ambiente)+":"+str(publico)+":"+str(animacion)+":"+str(pelicula)+"\n")
            archivo_genero.close()
            print("Modificacion Completada.")
        except Exception as error:
            print("Error de modificacion."+str(error))
    def leer_genero():#Leer genero
        print("Se muestra\nID:NOMBRE:ESTILO:AMBIENTACION:EDAD MINIMA DEL PUBLICO:ANIMACION(SI O NO):PELICULA")
        try:
            path = "./Genero.txt"
            archivo_genero = open(path, 'r')
            contenido = archivo_genero.readlines()
            for line in contenido:
                print(line)
            archivo_genero.close()
        except Exception as error:
            print("No se pudo leer"+ str(error))

# %%
class Pelicula:
    def __init__(self, id_pelicula, nombre_pelicula, anio, director, duracion, mayor):
        self.id_pelicula = id_pelicula
        self.nombre_pelicula = nombre_pelicula
        self.anio = anio
        self.director = director
        self.duracion = duracion
        self.mayor = mayor
    def agregar_pelicula(pelicula):#Agregr Pelicula
        try:
            path = "./Peliculas.txt"
            archivo_pelicula = open(path, 'a')
            for id_pelicula, nombre_pelicula, anio, director, duracion, mayor in pelicula:
                archivo_pelicula.write(str(id_pelicula)+":"+str(nombre_pelicula)+":"+str(anio)+":"
                                     +str(director)+":"+str(duracion)+":"+str(mayor)+"\n")
                
                
            print("Pelicula Guardada")
            archivo_pelicula.close()
        except Exception as error:
            print("Error al insertar Pelicula"+error)
    def buscar_pelicula(indice):#Buscar Pelicula
        try:
            pelicula = []
            path = "./Peliculas.txt"
            archivo_pelicula = open(path, 'r')
            for line in archivo_pelicula:
                id_pelicula, nombre_pelicula, anio, director, duracion, mayor = line.rstrip("\n").split(":")
                pelicula.append(((int(id_pelicula), nombre_pelicula, int(anio), director, float(duracion), bool(mayor))))
                valor = indice in nombre_pelicula
                print(valor)
                if valor:
                    print("Pelicula Encontrada")
                    print(pelicula)
            archivo_pelicula.close()
        except Exception as error:
            print("No se encontro"+ str(error))
    def eliminar_pelicula(indice):#Eliminar Pelicula
        try:
            pelicula = []
            path = "./Peliculas.txt"
            archivo_pelicula = open(path, 'r')
            path_temp = "./PeliculasTemporal.txt"
            archivo_pe_temp = open(path_temp, 'w')
            for line in archivo_pelicula:
                id_pelicula, nombre_pelicula, anio, director, duracion, mayor = line.rstrip("\n").split(":")
                pelicula.append(((int(id_pelicula), nombre_pelicula, int(anio), director, float(duracion), bool(mayor))))
                valor = indice in nombre_pelicula
                print(valor)
                if valor:
                    line_encontrada = line
            archivo_pelicula.close()
            pelicula = []
            path = "./Peliculas.txt"
            archivo_pelicula = open(path, 'r')
            path_temp = "./PeliculasTemporal.txt"
            archivo_pe_temp = open(path_temp, 'w')
            for line in archivo_pelicula:
                id_pelicula, nombre_pelicula, anio, director, duracion, mayor = line.rstrip("\n").split(":")
                pelicula.append(((int(id_pelicula), nombre_pelicula, int(anio), director, float(duracion), bool(mayor))))
                valor = indice in nombre_pelicula
                print(valor)
                if valor:
                    print("Pelicula Encontrada")
                    line_encontrada = line
            archivo_pelicula.close()
            path = "./Peliculas.txt"
            archivo_pelicula = open(path, 'r')
            for nueva_linea in archivo_pelicula:
                if line_encontrada != nueva_linea:
                    archivo_pe_temp.write(nueva_linea)
            archivo_pelicula.close()
            archivo_pe_temp.close()
            path = "./Peliculas.txt"
            archivo_pelicula = open(path, 'w')
            path_temp = "./PeliculasTemporal.txt"
            archivo_pe_temp = open(path_temp, 'r')
            for line_copiada in archivo_pe_temp:
                archivo_pelicula.write(line_copiada)
            archivo_pelicula.close()
            print("Se elimino exitosamente")
            archivo_pe_temp.close()
        except Exception as error:
            print("No encontro y no se pudo borrar"+str(error))
    def modificar_pelicula(indice):#Modificar pelicula
        try:
            pelicula = []
            path = "./Peliculas.txt"
            archivo_pelicula = open(path, 'r')
            path_temp = "./PeliculasTemporal.txt"
            archivo_pe_temp = open(path_temp, 'w')
            for line in archivo_pelicula:
                id_pelicula, nombre_pelicula, anio, director, duracion, mayor = line.rstrip("\n").split(":")
                pelicula.append(((int(id_pelicula), nombre_pelicula, int(anio), director, float(duracion), bool(mayor))))
                valor = indice in nombre_pelicula
                #print(valor)
                if valor:
                    line_encontrada = line
            archivo_pelicula.close()
            pelicula = []
            path = "./Peliculas.txt"
            archivo_pelicula = open(path, 'r')
            path_temp = "./PeliculasTemporal.txt"
            archivo_pe_temp = open(path_temp, 'w')
            for line in archivo_pelicula:
                id_pelicula, nombre_pelicula, anio, director, duracion, mayor = line.rstrip("\n").split(":")
                pelicula.append(((int(id_pelicula), nombre_pelicula, int(anio), director, float(duracion), bool(mayor))))
                valor = indice in nombre_pelicula
                #print(valor)
                if valor:
                    print("Pelicula Encontrada")
                    line_encontrada = line
            archivo_pelicula.close()
            path = "./Peliculas.txt"
            archivo_pelicula = open(path, 'r')
            for nueva_linea in archivo_pelicula:
                if line_encontrada != nueva_linea:
                    archivo_pe_temp.write(nueva_linea)
            archivo_pelicula.close()
            archivo_pe_temp.close()
            path = "./Peliculas.txt"
            archivo_pelicula = open(path, 'w')
            path_temp = "./PeliculasTemporal.txt"
            archivo_pe_temp = open(path_temp, 'r')
            for line_copiada in archivo_pe_temp:
                archivo_pelicula.write(line_copiada)
            archivo_pelicula.close()
            archivo_pe_temp.close()
            print("Registro econtrado")
            print(pelicula)
            #Formateo 
            id_pelicula = input("Nuevo ID: ")
            nombre_pelicula = input("Nuevo Nombre: ")
            anio = input("Nuevo Año: ")
            director = input("Nuevo Director: ")
            duracion = input("Nuevo Duracion(en miutos): ")
            mayor = input("Nuevo Mayor de edad(true o false): ")
            pelicula = [(id_pelicula,nombre_pelicula,anio,director,duracion,mayor)]

            path = "./Peliculas.txt"
            archivo_pelicula = open(path, 'a')
            for id_pelicula, nombre_pelicula, anio, director, duracion, mayor in pelicula:
                archivo_pelicula.write(str(id_pelicula)+":"+str(nombre_pelicula)+":"+str(anio)+":"
                                     +str(director)+":"+str(duracion)+":"+str(mayor)+"\n")
                
                
            print("Pelicula Guardada")
            archivo_pelicula.close()
            print("Modificacion Completada.")
        except Exception as error:
            print("Error de modificacion."+str(error))
    def leer_pelicula():##Leer pelicula
        print("Se muestra\nID:NOMBRE:AÑO:DIRECTOR:DURACION:PARA MAYORES DE EDAD")
        try:
            path = "./Peliculas.txt"
            archivo_pelicula = open(path, 'r')
            contenido = archivo_pelicula.readlines()
            for line in contenido:
                print(line)
            archivo_pelicula.close()
        except Exception as error:
            print("No se pudo leer"+ str(error))

# %%
class Main: 
    def opciones():
        print("OPCIONES")
        print("******************************************")
        print("GENERO")
        print("1: Insertar\n2: Leer\n3: Actualizar\n4: Eliminar\n5: Buscar")
        print("******************************************")
        print("PELICULA")
        print("6: Insertar\n7: Leer\n8: Actualizar\n9: Eliminar\n10: Buscar\n11: Salir")
    while True:
        opciones()
        opcion = input("Opcion: ")
        if(int(opcion) == 1):
            #Agredar el genero
            id_genero = input("ID: ")
            nombre_genero = input("Nombre: ")
            estilo = input("Estilo: ")
            ambiente = input("Ambientacion: ")
            publico = input("Edad minima Publico: ")
            animacion = input("Animacion(true or false): ")
            pelicula = input("Pelicula: ")
            genero = [(id_genero,nombre_genero,estilo,ambiente,publico,animacion, pelicula)]
            Genero.agregar_genero(genero)
            insert = input("Pelicula nueva (1) o Pelicula existente(2): ")
            if(int(insert)==1):
                id_pelicula = input("ID: ")
                nombre_pelicula = input("Nombre: ")
                anio = input("Año: ")
                director = input("Director: ")
                duracion = input("Duracion(en miutos): ")
                mayor = input("Mayores de edad(true or false): ")
                pelicula = [(id_pelicula,nombre_pelicula,anio,director,duracion,mayor)]
                Pelicula.agregar_pelicula(pelicula)
            elif(int(insert==2)):
                print("Genero guardado")

        elif(int(opcion) == 2):
            #Leer Genero 
            Genero.leer_genero()
        elif(int(opcion) == 3):
            #Modificar genero
            mod_genero = input("Nombre genero a modificar: ")
            Genero.modificar_genero(mod_genero)
        elif(int(opcion) == 4):
            #eliminar Genero 
            eli_genero = input("Nombre genero a eliminar: ")
            Genero.eliminar_genero(eli_genero)
        elif(int(opcion) == 5):
            #buscar Genero
            busca_genero = input("Nombre genero: ")
            Genero.buscar_genero(busca_genero)
        elif(int(opcion) == 6):
            #Agregar Pelicula
            id_pelicula = input("ID: ")
            nombre_pelicula = input("Nombre: ")
            anio = input("Año: ")
            director = input("Director: ")
            duracion = input("Duracion(en miutos): ")
            mayor = input("Mayores de edad(true or false): ")
            pelicula = [(id_pelicula,nombre_pelicula,anio,director,duracion,mayor)]
            Pelicula.agregar_pelicula(pelicula)
        elif(int(opcion) == 7):
            #Leer Pelicula
            Pelicula.leer_pelicula()
        elif(int(opcion) == 8):
            #Modificar Pelicula
            mod_pelicula = input("Nombre pelicula a modificar: ")
            Pelicula.modificar_pelicula(mod_pelicula)
        elif(int(opcion) == 9):
            #Eliminar pelicula
            eli_pelicula = input("Nombre pelcula a eliminar: ")
            Pelicula.eliminar_pelicula(eli_pelicula)
        elif(int(opcion) == 10):
            #Buscar Pelicula
            busca_pelicula = input("Nombre pelicula: ")
            Pelicula.buscar_pelicula(busca_pelicula)
        elif(int(opcion) == 11):
            print("Finalizado")
            break
        else:
            print("No selecciono una opción valida")
            input("Pulse una tecla para continuar.....")
# Out:
# OPCIONES
# ******************************************
# GENERO
# 1: Insertar
# 2: Leer
# 3: Actualizar
# 4: Eliminar
# 5: Buscar
# ******************************************
# PELICULA
# 6: Insertar
# 7: Leer
# 8: Actualizar
# 9: Eliminar
# 10: Buscar
# 11: Salir
# Opcion: 2
# Se muestra
# ID:NOMBRE:ESTILO:AMBIENTACION:EDAD MINIMA DEL PUBLICO:ANIMACION(SI O NO):PELICULA
# 1:Pepe:Testing:Testing2:18:false:Test
#
# OPCIONES
# ******************************************
# GENERO
# 1: Insertar
# 2: Leer
# 3: Actualizar
# 4: Eliminar
# 5: Buscar
# ******************************************
# PELICULA
# 6: Insertar
# 7: Leer
# 8: Actualizar
# 9: Eliminar
# 10: Buscar
# 11: Salir
# Opcion: 4
# Nombre genero a eliminar: Pepe
# Se elimino exitosamente
# OPCIONES
# ******************************************
# GENERO
# 1: Insertar
# 2: Leer
# 3: Actualizar
# 4: Eliminar
# 5: Buscar
# ******************************************
# PELICULA
# 6: Insertar
# 7: Leer
# 8: Actualizar
# 9: Eliminar
# ...
